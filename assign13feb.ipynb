# %%
#question1

#All the exceptions whether they are in built in python or are user defined or custom Exceptions are derived from the parent Base class Exception.
#Thus, by appling inheritance, in order to inherit the properties of Base Exception Class in Custom Exceptions, we use the Base Exception Class

# %%
#question2

# import inspect module
import inspect
  
# our treeClass function
def treeClass(cls, ind = 0):
    
      # print name of the class
    print ('-' * ind, cls.__name__)
      
    # iterating through subclasses
    for i in cls.__subclasses__():
        treeClass(i, ind + 3)
  
print("Hierarchy for Built-in exceptions is : ")
  
# inspect.getmro() Return a tuple 
# of class  cls’s base classes.
  
# building a tree hierarchy 
inspect.getclasstree(inspect.getmro(BaseException))
  
# function call
treeClass(BaseException)
# Out:
# Hierarchy for Built-in exceptions is :
#  BaseException
# --- Exception
# ------ TypeError
# --------- FloatOperation
# --------- MultipartConversionError
# ------ StopAsyncIteration
# ------ StopIteration
# ------ ImportError
# --------- ModuleNotFoundError
# --------- ZipImportError
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# ------------ ConnectionAbortedError
# ------------ ConnectionRefusedError
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# --------- BlockingIOError
# --------- ChildProcessError
# --------- FileExistsError
# --------- FileNotFoundError
# --------- IsADirectoryError
# --------- NotADirectoryError
# --------- InterruptedError
# ------------ InterruptedSystemCall
# --------- PermissionError
# --------- ProcessLookupError
# --------- TimeoutError
# --------- UnsupportedOperation
# --------- itimer_error
# --------- herror
# --------- gaierror
# --------- SSLError
# ------------ SSLCertVerificationError
# ...

# %%
#question3
#exception ArithmeticError
# This class is the base class for those built-in exceptions that are raised for various arithmetic errors such as :
# OverflowError
# ZeroDivisionError
# FloatingPointError

# 1)OverflowError is raised when a calculation produces a result that is too large to be represented by the available memory, 
#   such as an integer that exceeds the maximum value that can be stored. 
#   For example, in Python 3, the maximum value of an integer is 263 - 1, so attempting to calculate 21000 will result in an OverflowError.

# 2)FloatingPointError is raised when a floating-point calculation produces a result that cannot be represented exactly using the available memory, 
#   such as dividing by zero or calculating the square root of a negative number. 
#   For example, attempting to calculate the square root of -1 using math.sqrt(-1) will result in a FloatingPointError.

# %%
#question4

# The LookupError exception in Python forms the base class for all exceptions 
# that are raised when an index or a key is not found for a sequence or dictionary respectively.
# You can use LookupError exception class to handle both IndexError and KeyError exception classes.

#handling IndexError
try :
    l = [2,3,4,5]
    print(l[6])
except IndexError as e :
    print(e)

#handling KeyError
try :
    d = {"key" :"shivam" , 1 : [2,3,4,5]}
    print(d["key2"])
except KeyError as e : 
    print(e)
# Out:
# list index out of range
# 'key2'

# %%
#question5
# ImportError - indicates that you tried to import a module that Python doesn't find.
# ModuleNotFoundError is a subclass of ImportError.

try :
    import shiv
except ImportError as e :
    print(e)
# Out:
# No module named 'shiv'

# %%
#question6
# 1. use always a specific exception like ZeroDivisionError instead of just writing Except as a genric Exception handler.
# 2. print always a proper message along with exception.
# 3. always try to log your error.
# 4. alwyas avoid to write a multiple exception handling .
# 5. Document all the error .
# 6. dont forget to cleanup all the resources.
